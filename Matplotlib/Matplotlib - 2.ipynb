# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
fig,axes = plt.subplots()


axes.plot(x,y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-44bbf4cb101d> in <module>()
#       2
#       3
# ----> 4 axes.plot(x,y)
#       5
#       6
#
# NameError: name 'x' is not defined
